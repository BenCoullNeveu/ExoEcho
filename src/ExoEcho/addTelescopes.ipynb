# %%
import pandas as pd
from Functions import *
from Telescope import *
# import Ariel

import warnings
warnings.filterwarnings('ignore')

# %%
testspec = Telescope("Ariel TestSpec", 1, (1.10, 1.95), 1, 0.27, target_list_name=None)
testspec.constructTable()
# Out:
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel TestSpec 1.1-1.95um D=1 R=1 tau=0.27

# %%
df = pd.read_csv(f"{target_lists}Ariel_MCS_TPCs_2024-03-27.csv")
# remove unnamed columns
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#             TIC Star Name  Planet Name  Star Temperature [K]  \
# 0      65212867  TOI-1007  TOI-1007.01               6596.02
# 1     107782586  TOI-1009  TOI-1009.01               8868.70
# 2     341420329  TOI-1019  TOI-1019.01               7645.00
# 3      20318757  TOI-1027  TOI-1027.01               4272.00
# 4      20318757  TOI-1027  TOI-1027.02               4272.00
# ...         ...       ...          ...                   ...
# 2035  174599051   TOI-970   TOI-970.01               5189.00
# 2036   73038411   TOI-978   TOI-978.01               6368.00
# 2037  320536216   TOI-986   TOI-986.01               8031.00
# 2038   88684250   TOI-990   TOI-990.01               8388.00
# 2039    7561203   TOI-991   TOI-991.01               9855.00
#
#       Star Temperature Error Lower [K]  Star Temperature Error Upper [K]  \
# 0                               -139.2                             139.2
# 1                               -809.8                             809.8
# 2                               -134.4                             134.4
# 3                               -122.7                             122.7
# 4                               -122.7                             122.7
# ...                                ...                               ...
# 2035                            -121.3                             121.3
# 2036                            -126.8                             126.8
# 2037                            -181.1                             181.1
# 2038                            -125.1                             125.1
# 2039                            -169.3                             169.3
#
#       Star Radius [Rs]  Star Radius Error Lower [Rs]  \
# 0             2.702350                     -0.130000
# 1             2.184184                           NaN
# 2             1.562030                     -0.048126
# 3             0.680275                     -0.060000
# 4             0.680275                     -0.060000
# ...                ...                           ...
# 2035          1.065320                     -0.060000
# 2036          1.521490                     -0.070000
# 2037          1.645520                     -0.060000
# 2038          1.855080                     -0.070000
# 2039          2.132220                     -0.110000
#
#       Star Radius Error Upper [Rs]  Star log(g)  ...  Tier 3 Eclipses  \
# 0                         0.130000      3.71320  ...              5.0
# 1                              NaN          NaN  ...            134.0
# 2                         0.048126      4.30354  ...              1.0
# 3                         0.060000      4.59877  ...            599.0
# 4                         0.060000      4.59877  ...           5931.0
# ...                            ...          ...  ...              ...
# 2035                      0.060000      4.32759  ...            655.0
# 2036                      0.070000      4.17699  ...             41.0
# 2037                      0.060000      4.29326  ...             15.0
# 2038                      0.070000      4.21940  ...             19.0
# 2039                      0.110000      4.18181  ...             92.0
#
#       Preferred Method  Tier 1 Observations  Tier 2 Observations  \
# 0              Eclipse                  1.0                  2.0
# 1              Eclipse                  8.0                 67.0
# 2              Eclipse                  1.0                  1.0
# 3              Transit                  4.0                 41.0
# 4              Transit                  5.0                 46.0
# ...                ...                  ...                  ...
# 2035           Transit                  6.0                 69.0
# 2036           Eclipse                  3.0                 21.0
# 2037           Eclipse                  1.0                  7.0
# 2038           Eclipse                  1.0                 10.0
# 2039           Eclipse                  5.0                 46.0
#
#       Tier 3 Observations  FGS1_Flag  FGS2_Flag  FGS_Flag Max Tier  \
# 0                     5.0          0          0         0        2
# 1                   134.0          0          0         0        1
# 2                     1.0          0          0         0        3
# 3                    82.0          0          0         0        1
# 4                    92.0          0          0         0        1
# ...                   ...        ...        ...       ...      ...
# 2035                137.0          0          0         0        1
# 2036                 41.0          0          0         0        1
# 2037                 15.0          0          0         0        2
# 2038                 19.0          0          0         0        2
# 2039                 92.0          0          0         0        1
#
#      Dayside Emitting Temperature [K]
# 0                         1882.590382
# 1                         3156.937286
# 2                         1749.339510
# 3                          887.741765
# 4                          592.772548
# ...                               ...
# 2035                      1121.861053
# 2036                      1119.722550
# 2037                      3949.472097
# 2038                      2131.605422
# 2039                      3190.560983
#
# [2040 rows x 111 columns]

# %% [markdown]
# ## Constructing Ariel instrument objects (with known targets)

# %%
## TIER 1 ##
Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 1, 0.27).constructTable()
Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 3, 0.18).constructTable()
Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 1, 0.18).constructTable()


## TIER 2 ##
Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 10, 0.27).constructTable()
Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 50, 0.18).constructTable()
Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 10, 0.18).constructTable()


## TIER 3 ##
Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 20, 0.27).constructTable()
Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 100, 0.18).constructTable()
Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 30, 0.18).constructTable()

# photometric instruments
Telescope("Ariel FGS1", 1, (0.6, .8), 1, 0.17).constructTable()
Telescope("Ariel FGS2", 1, (0.8, 1.10), 1, 0.25).constructTable()
Telescope("Ariel VISPhot", 1, (0.5, .6), 1, 0.2).constructTable()

# Extra Instruments
# Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 15, 0.27).constructTable()
# Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 10, 0.27).constructTable()
# Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 100, 0.18).constructTable()
# Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 100, 0.18).constructTable()
# Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 30, 0.18).constructTable()
# Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 30, 0.18).constructTable()
# Out:
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel NIRSpec 1.1-1.95um D=1 R=1 tau=0.27
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel AIRS CH0 1.95-3.9um D=1 R=3 tau=0.18
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel AIRS CH1 3.9-7.8um D=1 R=1 tau=0.18
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel NIRSpec 1.1-1.95um D=1 R=10 tau=0.27
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel AIRS CH0 1.95-3.9um D=1 R=50 tau=0.18
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel AIRS CH1 3.9-7.8um D=1 R=10 tau=0.18
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel NIRSpec 1.1-1.95um D=1 R=20 tau=0.27
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel AIRS CH0 1.95-3.9um D=1 R=100 tau=0.18
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel AIRS CH1 3.9-7.8um D=1 R=30 tau=0.18
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel FGS1 0.6-0.8um D=1 R=1 tau=0.17
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel FGS2 0.8-1.1um D=1 R=1 tau=0.25
# No target list name provided. Loading default target list: Ariel_MCS_Known_2024-03-27. Use 'setTargetList' method to change target list.
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_Known_2024-03-27/Ariel VISPhot 0.5-0.6um D=1 R=1 tau=0.2

# %% [markdown]
# ## Constructing Ariel instrument objects (with TPCs)

# %%
## TIER 1 ##
Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 1, 0.27, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 3, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 1, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()


## TIER 2 ##
Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 10, 0.27, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 50, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 10, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()


## TIER 3 ##
Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 20, 0.27, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 100, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 30, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()

# photometric instruments
Telescope("Ariel FGS1", 1, (0.6, .8), 1, 0.17, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
Telescope("Ariel FGS2", 1, (0.8, 1.10), 1, 0.25, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
Telescope("Ariel VISPhot", 1, (0.5, .6), 1, 0.2, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()

# Extra Instruments
# Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 15, 0.27, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
# Telescope("Ariel NIRSpec", 1, (1.10, 1.95), 10, 0.27, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
# Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 100, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
# Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 100, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
# Telescope("Ariel AIRS CH0", 1, (1.95, 3.9), 30, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
# Telescope("Ariel AIRS CH1", 1, (3.9, 7.8), 30, 0.18, target_list_name="Ariel_MCS_TPCs_2024-03-27").constructTable()
# Out:
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel NIRSpec 1.1-1.95um D=1 R=1 tau=0.27
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel AIRS CH0 1.95-3.9um D=1 R=3 tau=0.18
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel AIRS CH1 3.9-7.8um D=1 R=1 tau=0.18
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel NIRSpec 1.1-1.95um D=1 R=10 tau=0.27
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel AIRS CH0 1.95-3.9um D=1 R=50 tau=0.18
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel AIRS CH1 3.9-7.8um D=1 R=10 tau=0.18
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel NIRSpec 1.1-1.95um D=1 R=20 tau=0.27
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel AIRS CH0 1.95-3.9um D=1 R=100 tau=0.18
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel AIRS CH1 3.9-7.8um D=1 R=30 tau=0.18
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel FGS1 0.6-0.8um D=1 R=1 tau=0.17
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel FGS2 0.8-1.1um D=1 R=1 tau=0.25
# /Users/ben_coull-neveu/Dropbox/- School -/Ariel Summer Internship 2024/EXOECHO_PACKAGE/ExoEcho/src/ExoEcho/Telescopes/Ariel/Ariel_MCS_TPCs_2024-03-27/Ariel VISPhot 0.5-0.6um D=1 R=1 tau=0.2

# %%
before = 60+10 #(+- 977ms)
after = 60+10 # (+- 1.55s)
improvement = before/after
deterioration = after/before

print(f"Improvement: {improvement}")
print(f"Deterioration: {deterioration}")
# Out:
# Improvement: 1.0
# Deterioration: 1.0

# %%
"hello good sir".__eq__("hello good sir")
# Out:
# True

# %%
# "JWST/NIRSpec 0.6-1.0 um", 6.5, 0.6, 1.0, 0.30

df_known = pd.read_csv("target_lists/Ariel_MCS_Known_2024-03-27.csv")
df_tpcs = pd.read_csv("target_lists/Ariel_MCS_TPCs_2024-03-27.csv")

# %%
Telescope("JWST NIRSpec 0.6-5.3um R=100", 6.5, (0.6, 5.3), 100, 0.36).constructTable()

# %%
addTelescope(df_known, "JWST NIRCam R=1600", 6.5, (2.4, 5.0), 1600, 0.36)

# %%
addTelescope(df_known, "JWST NIRSpec 0.6-5.3um R=100", 6.5, (0.6, 5.3), 100, 0.36)

# %%
addTelescope(df_known, "JWST NIRSpec 0.6-5.3um R=1000", 6.5, (0.6, 5.3), 1000, 0.36)

# %%
# addTelescope(df_known, "JWST NIRSpec 0.6-5.3um R=2700", 6.5, (0.6, 5.3), 2700, 0.30)

# %%
addTelescope(df_known,"JWST MIRI MRS 4.9-28.8um R=1500", 6.5, (4.9, 28.8), 1500, 0.18)

# %%
addTelescope(df_known, "JWST MIRI LRS 5.0-12.0um R=100", 6.5, (5, 12), 100, 0.18)

# %%
addTelescope(df_known, "JWST NIRISS SOSS 0.6-2.8um R=700", 6.5, (0.6, 2.8), 700, 0.2)  # http://jwst.astro.umontreal.ca/?page_id=51#:~:text=The%20SOSS%20throughput%20is%20the,with%20respect%20to%20the%20pupil.

#FOR MORE PLOTS WITH VARIOUS FILTERS: https://jwst-docs.stsci.edu/jwst-near-infrared-imager-and-slitless-spectrograph/niriss-instrumentation/niriss-filters#gsc.tab=0

# %%
addTelescope(df_known, "JWST NIRSpec G395H 2.87-5.14um R=100", 6.5, (2.87, 5.14), 100, 0.4)
# For NIRSpec G395H throughput and other: https://jwst-docs.stsci.edu/jwst-near-infrared-spectrograph/nirspec-performance#gsc.tab=0
# https://jwst-docs.stsci.edu/jwst-near-infrared-spectrograph/nirspec-instrumentation/nirspec-dispersers-and-filters#gsc.tab=0

# %%
addTelescope(df_known, "Ariel VISPhot 0.5-0.6um R=1", 1, (0.5, .6), 1, 0.27)
addTelescope(df_known, "Ariel FGS1 0.6-0.8um R=1", 1, (0.6, .8), 1, 0.17)
addTelescope(df_known, "Ariel FGS2 0.8-1.1um R=1", 1, (0.8, 1.10), 1, 0.25)
addTelescope(df_known, "Ariel NIRSpec 1.1-1.95um R=15", 1, (1.10, 1.95), 15, 0.27)
addTelescope(df_known, "Ariel AIRS-CH0 1.95-3.9um R=100", 1, (1.95, 3.9), 100, 0.18)
addTelescope(df_known, "Ariel AIRS-CH1 3.9-7.8um R=100", 1, (3.9, 7.8), 100, 0.18)
addTelescope(df_known, "Ariel AIRS-CH0 1.95-3.9um R=30", 1, (1.95, 3.9), 30, 0.18)
addTelescope(df_known, "Ariel AIRS-CH1 3.9-7.8um R=30", 1, (3.9, 7.8), 30, 0.18)

# See Ariel Definition of Study Report / Red Book

# %%
fig, ax = plt.subplots()

plotNoise("Telescopes/Ariel NIRSpec 1.1-1.95um R=15.csv", "Ariel NIRSpec", ax=ax, fill_between=True)
plotNoise("Telescopes/Ariel AIRS-CH0 1.95-3.9um R=30.csv", "Ariel AIRS-CH0", ax=ax, fill_between=True)
plotNoise("Telescopes/Ariel AIRS-CH1 3.9-7.8um R=30.csv", "Ariel AIRS-CH1", ax=ax, fill_between=True)

ax.text(1.1, 0.00019, "NIRSpec")
ax.text(1.25, 0.00000, "R=15")
ax.text(2.3, 0.00039, "AIRS-CH0")
ax.text(2.7, 0.00004, "R=30")
ax.text(5.2, 0.00065, "AIRS-CH1")
ax.text(5.7, 0.0001, "R=30")

ax.set_title("Noise Estimates for Various Ariel Instruments")

fig.savefig("Noise Estimate Plots/Noise Estimates for Various Ariel Instruments (R15 and R30).png", bbox_inches='tight', dpi=300)

plt.show()

# %%
fig, ax = plt.subplots()



plotNoise("Telescopes/Ariel NIRSpec 1.1-1.95um R=15.csv", "Ariel NIRSpec", ax=ax, fill_between=True)
plotNoise("Telescopes/Ariel AIRS-CH0 1.95-3.9um R=100.csv", "Ariel AIRS-CH0", ax=ax, fill_between=True)
plotNoise("Telescopes/Ariel AIRS-CH1 3.9-7.8um R=100.csv", "Ariel AIRS-CH1", ax=ax, fill_between=True)

ax.text(1.05, 0.0002, "NIRSpec")
ax.text(1.25, -0.00003, "R=15")
ax.text(2.3, 0.00071, "AIRS-CH0")
ax.text(2.7, 0.00009, "R=100")
ax.text(5.2, 0.00118, "AIRS-CH1")
ax.text(5.7, 0.00021, "R=100")

ax.set_title("Noise Estimates for Various Ariel Instruments")

fig.savefig("Noise Estimate Plots/Noise Estimates for Various Ariel Instruments (R15 and R100).png", bbox_inches='tight', dpi=300)

plt.show()
